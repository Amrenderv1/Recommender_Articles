# %%
import numpy as np
import scipy
import pandas as pd
import math
import random
import sklearn
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from scipy.sparse.linalg import svds
import matplotlib.pyplot as plt

# %%
articles_df = pd.read_csv('shared_articles.csv')
articles_df = articles_df[articles_df['eventType'] == 'CONTENT SHARED']
articles_df.head(100)
# Out:
#       timestamp       eventType            contentId       authorPersonId  \
# 1    1459193988  CONTENT SHARED -4110354420726924665  4340306774493623681
# 2    1459194146  CONTENT SHARED -7292285110016212249  4340306774493623681
# 3    1459194474  CONTENT SHARED -6151852268067518688  3891637997717104548
# 4    1459194497  CONTENT SHARED  2448026894306402386  4340306774493623681
# 5    1459194522  CONTENT SHARED -2826566343807132236  4340306774493623681
# 6    1459194557  CONTENT SHARED -2148899391355011268  4340306774493623681
# 7    1459194599  CONTENT SHARED  4119190424078847945  4340306774493623681
# 8    1459194751  CONTENT SHARED -7926018713416777892  4340306774493623681
# 9    1459194842  CONTENT SHARED  3353902017498793780  4340306774493623681
# 10   1459210504  CONTENT SHARED -9157338616628196758  5206835909720479405
# 11   1459217624  CONTENT SHARED  1805789466376069146 -1032019229384696495
# 12   1459217735  CONTENT SHARED -2081760549863309770 -1032019229384696495
# 13   1459217994  CONTENT SHARED -5170198873410718233 -1032019229384696495
# 14   1459229160  CONTENT SHARED -3367778232969996503 -1032019229384696495
# 15   1459248284  CONTENT SHARED  4988225165850707692  4670267857749552625
# 16   1459248366  CONTENT SHARED -5917314377186856799  4670267857749552625
# 17   1459248432  CONTENT SHARED  6157037646878010131  4670267857749552625
# 18   1459251677  CONTENT SHARED  6023609667389715259  4340306774493623681
# 19   1459251714  CONTENT SHARED  7905485530310717815  4340306774493623681
# 20   1459251799  CONTENT SHARED  8194079557551008273  4340306774493623681
# 21   1459251851  CONTENT SHARED -1672166631728511207  4340306774493623681
# 22   1459251889  CONTENT SHARED -4374331682165863764  4340306774493623681
# 23   1459257477  CONTENT SHARED  5714314286511882372  1895326251577378793
# 24   1459257584  CONTENT SHARED -8141818108252244664  1895326251577378793
# 25   1459257924  CONTENT SHARED -8939172344092554931 -1443636648652872475
# 26   1459258094  CONTENT SHARED -1591454024897803197 -8606085472606356565
# 27   1459259981  CONTENT SHARED -6874540813378776198  -108842214936804958
# 28   1459268727  CONTENT SHARED -3173020603774823976 -1032019229384696495
# 29   1459268965  CONTENT SHARED -9107331682787867601 -1032019229384696495
# 30   1459269196  CONTENT SHARED -1021685224930603833  4670267857749552625
# ..          ...             ...                  ...                  ...
# 73   1459356250  CONTENT SHARED   787067277772219433  3891637997717104548
# 74   1459358379  CONTENT SHARED -2778760500673113802  4340306774493623681
# 75   1459358408  CONTENT SHARED -6725796505137573953  4340306774493623681
# 76   1459358437  CONTENT SHARED  1457728991321948254  4340306774493623681
# 77   1459358457  CONTENT SHARED -7101541512657907485  4340306774493623681
# 78   1459359876  CONTENT SHARED  5281570276277574938 -1578287561410088674
# 79   1459361227  CONTENT SHARED  1128840733277618400 -1443636648652872475
# 80   1459366951  CONTENT SHARED -7356135999773525293 -1443636648652872475
# 81   1459367363  CONTENT SHARED  2313825045587317872  3891637997717104548
# 82   1459367504  CONTENT SHARED  -518690781085251687  3891637997717104548
# 83   1459367565  CONTENT SHARED  3067875254349597654  4340306774493623681
# 85   1459367829  CONTENT SHARED  5619251370090681244  3891637997717104548
# 86   1459367885  CONTENT SHARED  7420742904084384944 -1443636648652872475
# 88   1459368454  CONTENT SHARED  8219310215587599928 -1443636648652872475
# 89   1459368501  CONTENT SHARED  7748594134538052724 -1443636648652872475
# 91   1459369111  CONTENT SHARED -4186591400427142356  3609194402293569455
# 92   1459369124  CONTENT SHARED  8565115980515859979  3891637997717104548
# 93   1459369515  CONTENT SHARED  8082202054464515448 -7531858294361854119
# 94   1459369531  CONTENT SHARED -5973686110278905367  4670267857749552625
# 95   1459373698  CONTENT SHARED -9172673334835262304 -2626634673110551643
# 96   1459374054  CONTENT SHARED -1039912738963181810  -709287718034731589
# 97   1459375727  CONTENT SHARED  3172866488852888544 -1032019229384696495
# 98   1459378041  CONTENT SHARED  8095004770374551394  8341545449730058951
# 99   1459382038  CONTENT SHARED  8801106199759296338  8341545449730058951
# 100  1459391011  CONTENT SHARED -4760639635023250284  3891637997717104548
# 101  1459391950  CONTENT SHARED -9137036168156595470  3891637997717104548
# 102  1459393651  CONTENT SHARED  -454649054276160610 -2525380383541287600
# 103  1459393730  CONTENT SHARED   -36844712915106340 -2525380383541287600
# 104  1459393837  CONTENT SHARED  5333141914314968598 -2525380383541287600
# 105  1459394988  CONTENT SHARED -8248141950199177506  3891637997717104548
#
#          authorSessionId authorUserAgent authorRegion authorCountry  \
# 1    8940341205206233829             NaN          NaN           NaN
# 2    8940341205206233829             NaN          NaN           NaN
# 3   -1457532940883382585             NaN          NaN           NaN
# 4    8940341205206233829             NaN          NaN           NaN
# 5    8940341205206233829             NaN          NaN           NaN
# 6    8940341205206233829             NaN          NaN           NaN
# 7    8940341205206233829             NaN          NaN           NaN
# 8    8940341205206233829             NaN          NaN           NaN
# 9    8940341205206233829             NaN          NaN           NaN
# 10  -7864441319395545950             NaN          NaN           NaN
# 11   3042342415047984532             NaN          NaN           NaN
# 12   3042342415047984532             NaN          NaN           NaN
# 13   3042342415047984532             NaN          NaN           NaN
# 14   3042342415047984532             NaN          NaN           NaN
# 15   -265833983523746108             NaN          NaN           NaN
# 16   -265833983523746108             NaN          NaN           NaN
# 17   -265833983523746108             NaN          NaN           NaN
# 18  -7292854281461484137             NaN          NaN           NaN
# 19  -7292854281461484137             NaN          NaN           NaN
# 20  -7292854281461484137             NaN          NaN           NaN
# 21  -7292854281461484137             NaN          NaN           NaN
# 22  -7292854281461484137             NaN          NaN           NaN
# 23   6290959012079283980             NaN          NaN           NaN
# 24   6290959012079283980             NaN          NaN           NaN
# 25  -9071650721576979280             NaN          NaN           NaN
# 26   7660662789565329118             NaN          NaN           NaN
# 27    770918631519434453             NaN          NaN           NaN
# 28   3042342415047984532             NaN          NaN           NaN
# 29   3042342415047984532             NaN          NaN           NaN
# 30   -265833983523746108             NaN          NaN           NaN
# ..                   ...             ...          ...           ...
# 73   1776955132850411647             NaN          NaN           NaN
# 74   -498266315041649697             NaN          NaN           NaN
# 75   -498266315041649697             NaN          NaN           NaN
# 76   -498266315041649697             NaN          NaN           NaN
# 77   -498266315041649697             NaN          NaN           NaN
# 78  -7549635179522179894             NaN          NaN           NaN
# 79   8209530310193218854             NaN          NaN           NaN
# 80   8209530310193218854             NaN          NaN           NaN
# 81   1776955132850411647             NaN          NaN           NaN
# 82   -910102441365544094             NaN          NaN           NaN
# 83   -498266315041649697             NaN          NaN           NaN
# 85   -910102441365544094             NaN          NaN           NaN
# 86   8209530310193218854             NaN          NaN           NaN
# 88   8209530310193218854             NaN          NaN           NaN
# 89   8209530310193218854             NaN          NaN           NaN
# 91   8227849995987463182             NaN          NaN           NaN
# 92   1776955132850411647             NaN          NaN           NaN
# 93    681809534976157585             NaN          NaN           NaN
# 94    204912088629071541             NaN          NaN           NaN
# 95   2243107847559315523             NaN          NaN           NaN
# 96  -8526179123269437438             NaN          NaN           NaN
# 97  -1858408872346331823             NaN          NaN           NaN
# 98  -5545744138755137267             NaN          NaN           NaN
# 99  -5545744138755137267             NaN          NaN           NaN
# 100  -910102441365544094             NaN          NaN           NaN
# 101  -910102441365544094             NaN          NaN           NaN
# 102 -7250107190098654804             NaN          NaN           NaN
# 103 -7250107190098654804             NaN          NaN           NaN
# 104 -7250107190098654804             NaN          NaN           NaN
# 105  -910102441365544094             NaN          NaN           NaN
#
#     contentType                                                url  \
# 1          HTML  http://www.nytimes.com/2016/03/28/business/dea...
# 2          HTML  http://cointelegraph.com/news/bitcoin-future-w...
# 3          HTML  https://cloudplatform.googleblog.com/2016/03/G...
# 4          HTML  https://bitcoinmagazine.com/articles/ibm-wants...
# 5          HTML  http://www.coindesk.com/ieee-blockchain-oxford...
# 6          HTML  http://www.newsbtc.com/2016/03/28/banks-need-c...
# 7          HTML  https://bitcoinmagazine.com/articles/blockchai...
# 8          HTML  https://news.bitcoin.com/conglomerates-intervi...
# 9          HTML  https://www.cryptocoinsnews.com/ethereum-rise-...
# 10         HTML  http://economia.ig.com.br/2016-03-27/situacao-...
# 11         HTML  https://cloud.google.com/compute/docs/load-bal...
# 12         HTML  https://cloud.google.com/compute/docs/load-bal...
# 13         HTML  http://techcrunch.com/2016/03/28/ntt-to-buy-de...
# 14         HTML  http://www.salon.com/2016/03/27/good_riddance_...
# 15         HTML  http://cio.economictimes.indiatimes.com/news/i...
# 16         HTML  http://www.senar.org.br/agricultura-precisao/a...
# 17         HTML  https://www.macroprograma1.cnptia.embrapa.br/r...
# 18         HTML  https://blog.coinfund.io/five-bitcoin-and-ethe...
# 19         HTML  http://www.coindesk.com/blockchain-smart-contr...
# 20         HTML  http://bitcoinist.net/using-gamified-hacking-c...
# 21         HTML  https://www.coinbr.net/blog/america-latina-apr...
# 22         HTML          http://www.bbc.com/news/business-35890616
# 23         HTML  https://www.sympla.com.br/como-startups-e-gran...
# 24         HTML  https://www.sympla.com.br/pimp-my-pitch-como-f...
# 25         HTML  http://kotaku.com/google-deepmind-is-now-analy...
# 26         HTML  http://recruitingdaily.com/how-okcupid-changed...
# 27         HTML  https://medium.com/greylock-perspectives/the-h...
# 28         HTML  https://nodejs.org/en/blog/announcements/welco...
# 29         HTML  http://techcrunch.com/2016/03/29/hopper-raises...
# 30         HTML  http://www.telequest.com.br/portal/index.php/o...
# ..          ...                                                ...
# 73         HTML  https://zoocha.com/blog/setting-drupal-code-sn...
# 74         HTML  http://cointelegraph.com/news/bitcoin-mining-e...
# 75         HTML    http://www.thebitcoinchannel.com/archives/55850
# 76         HTML  http://blogs.wsj.com/moneybeat/2016/03/29/wall...
# 77         HTML  http://www.coindesk.com/nominations-2016-block...
# 78         HTML  https://azure.microsoft.com/en-us/services/cog...
# 79         HTML  http://www.techrepublic.com/article/google-adm...
# 80         HTML  http://www.popsci.com/byzantine-science-deceiv...
# 81         HTML  https://labs.spotify.com/2016/03/10/spotifys-e...
# 82         HTML  https://quizlet.com/blog/whats-the-best-cloud-...
# 83         HTML  http://www.coindesk.com/microsoft-ethereum-3-m...
# 85         HTML  https://cloud.google.com/docs/google-cloud-pla...
# 86         HTML  http://www.popsci.com/byzantine-science-deceiv...
# 88         HTML  http://www.popsci.com/byzantine-science-deceiv...
# 89         HTML  http://www.popsci.com/byzantine-science-deceiv...
# 91         HTML  http://www.b9.com.br/64171/social-media/em-par...
# 92         HTML  https://cloudplatform.googleblog.com/2016/03/c...
# 93         HTML  http://www.b9.com.br/64132/tech/com-hololens-m...
# 94         HTML  http://www.mckinsey.com/industries/high-tech/o...
# 95         HTML  http://g1.globo.com/sao-paulo/sorocaba-jundiai...
# 96         HTML  http://9to5mac.com/2016/03/30/apple-launches-s...
# 97         HTML  http://www.fastcodesign.com/3058294/google-is-...
# 98         HTML  http://www.theverge.com/2016/3/30/11317924/mic...
# 99         HTML          http://www.bbc.com/news/business-35923885
# 100        HTML  https://cloudplatform.googleblog.com/2016/02/S...
# 101        HTML  http://us8.campaign-archive1.com/?u=eb2d2e4ce4...
# 102        HTML  https://blogs.windows.com/windowsexperience/20...
# 103        HTML  https://blogs.windows.com/buildingapps/2016/03...
# 104        HTML  https://blogs.windows.com/devices/2016/03/18/m...
# 105        HTML  https://dev.acquia.com/blog/how-we-migrated-da...
#
#                                                  title  \
# 1    Ethereum, a Virtual Currency, Enables Transact...
# 2    Bitcoin Future: When GBPcoin of Branson Wins O...
# 3                         Google Data Center 360° Tour
# 4    IBM Wants to "Evolve the Internet" With Blockc...
# 5    IEEE to Talk Blockchain at Cloud Computing Oxf...
# 6    Banks Need To Collaborate With Bitcoin and Fin...
# 7    Blockchain Technology Could Put Bank Auditors ...
# 8    Why Decentralized Conglomerates Will Scale Bet...
# 9    The Rise And Growth of Ethereum Gets Mainstrea...
# 10   Situação financeira ruim de varejistas pressio...
# 11                   Setting Up HTTP(S) Load Balancing
# 12   Setting Up SSL proxy for Google Cloud Load Bal...
# 13   NTT to buy Dell's services division for $3.05 ...
# 14   Good riddance, gig economy: Uber, Ayn Rand and...
# 15           The internet of a billion things | ET CIO
# 16   Artigos e Palestras - Programa Agricultura de ...
# 17                     Rede Agricultura de Precisão II
# 18   Five Bitcoin and Ethereum Based Projects to Wa...
# 19   Blockchain Smart Contracts Startup Selected By...
# 20   Using Gamified Hacking Challenges To Attract N...
# 21            O potencial do bitcoin na América Latina
# 22   From fine wine to lotteries: Blockchain tech t...
# 23   Como Startups e Grandes Empresas podem colabor...
# 24         Pimp My Pitch: como fazer um Pitch poderoso
# 25   Google DeepMind Is Now Analysing Magic And Hea...
# 26                 How OKCupid Changed Hiring Forever.
# 27   The Hierarchy of Engagement - Greylock Perspec...
# 28                      Welcome Google Cloud Platform!
# 29   Hopper raises $16 million for a travel app tha...
# 30             Indústria 4.0: desafios e oportunidades
# ..                                                 ...
# 73                      Setting up Drupal Code Sniffer
# 74   Bitcoin Mining, Ethereum Mining, Cloud Mining:...
# 75   Stratumn is building a sort of Heroku for bloc...
# 76                Wall Street Goes Big on Bitcoin Tech
# 77   Coin Center Opens Nominations for the 2016 Blo...
# 78   Cognitive Services-Intelligence Applications |...
# 79   Google admits original enterprise cloud strate...
# 80                                 Fooling The Machine
# 81   Spotify's Event Delivery - The Road to the Clo...
# 82                 What's the Best Cloud? Probably GCP
# 83   Microsoft Adds Ethereum to Windows Platform Fo...
# 85         Google Cloud Platform for AWS Professionals
# 86                                 Fooling The Machine
# 88                                 Fooling The Machine
# 89                                 Fooling The Machine
# 91   Em parceria com Facebook, KLM passa a oferecer...
# 92   Calculating and searching 500 billion digits o...
# 93   Com HoloLens, Microsoft torna realidade a mens...
# 94                              The Internet of Things
# 95          Tecnologia para colher mais e o uso do GPS
# 96   Apple launches Safari Technology Preview, a br...
# 97   Google Is Finally Redesigning Its Biggest Cash...
# 98   Microsoft Build: the 10 most important announc...
# 99         Foxconn finalises Sharp takeover - BBC News
# 100  Spotify chooses Google Cloud Platform to power...
# 101  New blog from Dries: A "MAP" for accelerating ...
# 102                     The Future of Pen: Windows Ink
# 103  Windows 10 Anniversary SDK is bringing excitin...
# 104  Microsoft HoloLens and Lowe's, working to rede...
# 105  How We Migrated Data into Drupal from Four Dif...
#
#                                                   text lang
# 1    All of this work is still very early. The firs...   en
# 2    The alarm clock wakes me at 8:00 with stream o...   en
# 3    We're excited to share the Google Data Center ...   en
# 4    The Aite Group projects the blockchain market ...   en
# 5    One of the largest and oldest organizations fo...   en
# 6    It will take time until banks come around to t...   en
# 7    When most people think about computers and rob...   en
# 8    Bitcoin.com spoke with the OpenLedger CEO, Ron...   en
# 9    Ethereum, considered by many to be the most pr...   en
# 10   A queda nas vendas e a deterioração na situaçã...   pt
# 11   HTTP(S) load balancing provides global load ba...   en
# 12   Alpha This is an Alpha release of Setting Up S...   en
# 13   You may know Dell as a computer and server mak...   en
# 14   The Uber model just doesn't work for other ind...   en
# 15   Industrial adoption of IoT dubbed as Industria...   en
# 16   Artigos e Palestras ARTIGOS / 2015 12/08/2015 ...   pt
# 17   Do Se Te Qu Qu Se Sa 27 28 29 30 31 Faça downl...   pt
# 18   Five Bitcoin and Ethereum Based Projects to Wa...   en
# 19   CommonAccord, a blockchain-based startup for l...   en
# 20   The blockchain ecosystem is always in need of ...   en
# 21   28/03/2016 | por Safiri Felix | em Economia As...   pt
# 22   Imagine a world where you can vote in an elect...   en
# 23   Muito tem se falado sobre como grandes empresa...   pt
# 24   Descrição do evento Qual horário? 14h00min às ...   pt
# 25   With retro games and Go well-conquered , where...   en
# 26   Twenty years ago, if you wanted to find a spec...   en
# 27   The Hierarchy of Engagement The Fuel to Build ...   en
# 28   Google Cloud Platform joined the Node.js Found...   en
# 29   Hopper , the makers of a handy travel applicat...   en
# 30   *Igor Schiewig 25/03/2016 - A Indústria 4.0 é ...   pt
# ..                                                 ...  ...
# 73   A few weeks ago I had to go through the proces...   en
# 74   Bitcoin saw a surge in price between March 201...   en
# 75   techcrunch.com / Romain Dillet / March 29, 201...   en
# 76   The mainstreaming of bitcoin tech continues. N...   en
# 77   The Blockchain Awards, last held in 2014, are ...   en
# 78   Build powerful intelligence into your applicat...   en
# 79   Image: Andy Wolber/TechRepublic Meet Google, a...   en
# 80   Two groups, one at Berkeley University and ano...   en
# 81   Whenever a user performs an action in the Spot...   en
# 82   In 2015 we migrated Quizlet from our legacy ho...   en
# 83   Millions of Microsoft developers are now able ...   en
# 85   This guide is designed to equip professionals ...   en
# 86   Two groups, one at Berkeley University and ano...   en
# 88   Two groups, one at Berkeley University and ano...   en
# 89   Two groups, one at Berkeley University and ano...   en
# 91   Facebook e KLM anunciaram hoje uma parceria qu...   pt
# 92   It's Pi day! Have you ever wondered whether yo...   en
# 93   As recentes demonstrações do HoloLens da Micro...   pt
# 94   More objects are becoming embedded with sensor...   en
# 95   Na fazenda em Maracaí (SP), a colheita já era ...   pt
# 96   Apple today announced a new browser, sort of. ...   en
# 97   Google made $74 billion last year. And it wasn...   en
# 98   Here come the bots! Every year, Microsoft hold...   en
# 99   Taiwanese manufacturer Foxconn says it has fin...   en
# 100  It's not every day you move a 75 million+ user...   en
# 101  Contributed modules in Drupal deliver the func...   en
# 102  What a day at //build 2016! We're very proud o...   en
# 103  Hello from Build 2016! I just had an opportuni...   en
# 104  Today, we're thrilled to announce that Microso...   en
# 105  The Scenario Some time ago we were contacted b...   en
#
# [100 rows x 13 columns]

# %%
interactions_df = pd.read_csv('users_interactions.csv')
interactions_df.head(101)
# Out:
#       timestamp        eventType            contentId             personId  \
# 0    1465413032             VIEW -3499919498720038879 -8845298781299428018
# 1    1465412560             VIEW  8890720798209849691 -1032019229384696495
# 2    1465416190             VIEW   310515487419366995 -1130272294246983140
# 3    1465413895           FOLLOW   310515487419366995   344280948527967603
# 4    1465412290             VIEW -7820640624231356730  -445337111692715325
# 5    1465413742             VIEW   310515487419366995 -8763398617720485024
# 6    1465415950             VIEW -8864073373672512525  3609194402293569455
# 7    1465415066             VIEW -1492913151930215984  4254153380739593270
# 8    1465413762             VIEW   310515487419366995   344280948527967603
# 9    1465413771             VIEW  3064370296170038610  3609194402293569455
# 10   1465413864             VIEW   310515487419366995  3609194402293569455
# 11   1465415229             VIEW  3460026829794173084  1908339160857512799
# 12   1465415228             VIEW  3460026829794173084  1908339160857512799
# 13   1465415691             VIEW  7763750328910542816  1908339160857512799
# 14   1465413171             VIEW  2372438485070148864  7781822014935525018
# 15   1465415259             VIEW  -348408475077850711  8239286975497580612
# 16   1465415623             VIEW   372531153711028286  8239286975497580612
# 17   1465412288             VIEW -7820640624231356730  -445337111692715325
# 18   1465415693             VIEW  6521856301289868251  2766187446275090740
# 19   1465415691             VIEW -8142426490949346803  1908339160857512799
# 20   1465416196             VIEW   310515487419366995 -1130272294246983140
# 21   1465415431             VIEW  7943088471380012839  8239286975497580612
# 22   1465415060             VIEW -1492913151930215984  4254153380739593270
# 23   1465413743             VIEW   310515487419366995 -8763398617720485024
# 24   1465415565             VIEW  1441248639512899483  8239286975497580612
# 25   1465413879         BOOKMARK   310515487419366995  3609194402293569455
# 26   1465415695             VIEW  7763750328910542816  1908339160857512799
# 27   1465413954         BOOKMARK   310515487419366995 -8763398617720485024
# 28   1465413735             VIEW -1492913151930215984  3609194402293569455
# 29   1465414324             VIEW  4306804750094230211 -1479311724257856983
# ..          ...              ...                  ...                  ...
# 71   1466034818  COMMENT CREATED -4205346868684833897 -1032019229384696495
# 72   1466034237             VIEW -4205346868684833897 -1387464358334758758
# 73   1460566380             LIKE  3727587882617538492 -1602833675167376798
# 74   1460566003             VIEW  -692972306229904743 -1602833675167376798
# 75   1460566746             VIEW -7777013191403056825  5621833459783231486
# 76   1460566250             VIEW -4615575698508618335 -2626634673110551643
# 77   1460566179             VIEW  3727587882617538492 -1602833675167376798
# 78   1460566517           FOLLOW  4761910285123871012  -108842214936804958
# 79   1460566919             VIEW  4761910285123871012 -6153009241569363021
# 80   1460568722             VIEW  5688279681867464747 -4585796377251906117
# 81   1460566378             VIEW  3727587882617538492 -1602833675167376798
# 82   1460566382             VIEW  3727587882617538492 -1602833675167376798
# 83   1460566210             VIEW  4761910285123871012  -108842214936804958
# 84   1460567442             VIEW -1470592927114056630 -2339455719722814827
# 85   1460566763             VIEW  3172866488852888544  5621833459783231486
# 86   1460566388             VIEW  -692972306229904743 -1602833675167376798
# 87   1460569552             VIEW -2261845840076552387  4340306774493623681
# 88   1460566765             VIEW  -998818216447049475  5621833459783231486
# 89   1460566421             VIEW  4761910285123871012  5683029675627635125
# 90   1460567374             VIEW -2181071289972835602 -1443636648652872475
# 91   1460570095             VIEW  1964631817676172382  3891637997717104548
# 92   1460566310             VIEW  4761910285123871012  -108842214936804958
# 93   1460566083             VIEW -8418620743404378592 -2050699458865052139
# 94   1460565500             VIEW  4761910285123871012  3429602690322213789
# 95   1460566206             VIEW  1431351528207086249 -2626634673110551643
# 96   1460566393             LIKE  -692972306229904743 -1602833675167376798
# 97   1460570179             VIEW -8971085667828564532 -1443636648652872475
# 98   1460568694             VIEW -2181071289972835602 -1443636648652872475
# 99   1460568778             VIEW -2261845840076552387  4340306774493623681
# 100  1460567399             VIEW -5557505576293652420 -2772844562500836582
#
#                sessionId                                          userAgent  \
# 0    1264196770339959068                                                NaN
# 1    3621737643587579081  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2...
# 2    2631864456530402479                                                NaN
# 3   -3167637573980064150                                                NaN
# 4    5611481178424124714                                                NaN
# 5    1395789369402380392  Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebK...
# 6    1143207167886864524                                                NaN
# 7    8743229464706506141  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 8   -3167637573980064150                                                NaN
# 9    1143207167886864524                                                NaN
# 10   1143207167886864524                                                NaN
# 11   9121879357144259163                                                NaN
# 12   9121879357144259163  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 13   9121879357144259163  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 14  -8307903816792524795                                                NaN
# 15   8524822173689882396  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 16   8524822173689882396  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 17   5611481178424124714  Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebK...
# 18    247949759466213096  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 19   9121879357144259163                                                NaN
# 20   2631864456530402479  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_1...
# 21   8524822173689882396  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 22   8743229464706506141                                                NaN
# 23   1395789369402380392                                                NaN
# 24   8524822173689882396  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 25   1143207167886864524                                                NaN
# 26   9121879357144259163                                                NaN
# 27   1395789369402380392                                                NaN
# 28   1143207167886864524  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 29   5326691377159417610  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# ..                   ...                                                ...
# 71  -5537786999103108189                                                NaN
# 72   5111485313337394011                                                NaN
# 73   6423946716608697521                                                NaN
# 74   6423946716608697521                        Android - Native Mobile App
# 75  -5286822267520919579  Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebK...
# 76  -8667089667511961357  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_4...
# 77   6423946716608697521                        Android - Native Mobile App
# 78  -9137723263631808218                                                NaN
# 79   5535103204328988707  Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebK...
# 80   -781311598216662665  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_4...
# 81   6423946716608697521                        Android - Native Mobile App
# 82   6423946716608697521                        Android - Native Mobile App
# 83  -9137723263631808218  Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKi...
# 84  -1789899936957554863  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 85  -5286822267520919579  Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebK...
# 86   6423946716608697521                        Android - Native Mobile App
# 87   6173407106018486716  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_5...
# 88  -5286822267520919579  Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebK...
# 89  -7044888500585609425  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 90  -7298018010644449122  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 91  -8565657953856638124  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_3...
# 92  -9137723263631808218  Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKi...
# 93    439898712475129302  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 94   -809468356280474688  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_0...
# 95  -8667089667511961357  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_4...
# 96   6423946716608697521                                                NaN
# 97  -7298018010644449122  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 98  -7298018010644449122  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 99   6173407106018486716  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_5...
# 100 -4457986168060768634                        Android - Native Mobile App
#
#     userRegion userCountry
# 0          NaN         NaN
# 1           NY          US
# 2          NaN         NaN
# 3          NaN         NaN
# 4          NaN         NaN
# 5           MG          BR
# 6          NaN         NaN
# 7           SP          BR
# 8          NaN         NaN
# 9          NaN         NaN
# 10         NaN         NaN
# 11         NaN         NaN
# 12          SP          BR
# 13          SP          BR
# 14         NaN         NaN
# 15          SP          BR
# 16          SP          BR
# 17          MG          BR
# 18          MG          BR
# 19         NaN         NaN
# 20          SP          BR
# 21          SP          BR
# 22         NaN         NaN
# 23         NaN         NaN
# 24          SP          BR
# 25         NaN         NaN
# 26         NaN         NaN
# 27         NaN         NaN
# 28          SP          BR
# 29          SP          BR
# ..         ...         ...
# 71         NaN         NaN
# 72         NaN         NaN
# 73         NaN         NaN
# 74          SP          BR
# 75          MG          BR
# 76          GA          US
# 77          SP          BR
# 78         NaN         NaN
# 79          MG          BR
# 80          SP          BR
# 81          SP          BR
# 82          SP          BR
# 83          SP          BR
# 84          CA          US
# 85          MG          BR
# 86          SP          BR
# 87          SP          BR
# 88          MG          BR
# 89          SP          BR
# 90          SP          BR
# 91          SP          BR
# 92          SP          BR
# 93          SP          BR
# 94          SP          BR
# 95          GA          US
# 96         NaN         NaN
# 97          SP          BR
# 98          SP          BR
# 99          SP          BR
# 100         SP          BR
#
# [101 rows x 8 columns]

# %%
event_type_strength = {
   'VIEW': 1.0,
   'LIKE': 2.0, 
   'BOOKMARK': 2.5, 
   'FOLLOW': 3.0,
   'COMMENT CREATED': 4.0,  
}

interactions_df['eventStrength'] = interactions_df['eventType'].apply(lambda x: event_type_strength[x])

# %%
users_interactions_count_df = interactions_df.groupby(['personId', 'contentId']).size().groupby('personId').size()
print('# users: %d' % len(users_interactions_count_df))
users_with_enough_interactions_df = users_interactions_count_df[users_interactions_count_df >= 5].reset_index()[['personId']]
print('# users with at least 5 interactions: %d' % len(users_with_enough_interactions_df))
# Out:
# # users: 1895
# # users with at least 5 interactions: 1140

# %%
print('# of interactions: %d' % len(interactions_df))
interactions_from_selected_users_df = interactions_df.merge(users_with_enough_interactions_df, 
               how = 'right',
               left_on = 'personId',
               right_on = 'personId')
print('# of interactions from users with at least 5 interactions: %d' % len(interactions_from_selected_users_df))
# Out:
# # of interactions: 72312
# # of interactions from users with at least 5 interactions: 69868

# %%
def smooth_user_preference(x):
    return math.log(1+x, 2)
    
interactions_full_df = interactions_from_selected_users_df \
                    .groupby(['personId', 'contentId'])['eventStrength'].sum() \
                    .apply(smooth_user_preference).reset_index()
print('# of unique user/item interactions: %d' % len(interactions_full_df))
interactions_full_df.head(10)
# Out:
# # of unique user/item interactions: 39106
#               personId            contentId  eventStrength
# 0 -9223121837663643404 -8949113594875411859       1.000000
# 1 -9223121837663643404 -8377626164558006982       1.000000
# 2 -9223121837663643404 -8208801367848627943       1.000000
# 3 -9223121837663643404 -8187220755213888616       1.000000
# 4 -9223121837663643404 -7423191370472335463       3.169925
# 5 -9223121837663643404 -7331393944609614247       1.000000
# 6 -9223121837663643404 -6872546942144599345       1.000000
# 7 -9223121837663643404 -6728844082024523434       1.000000
# 8 -9223121837663643404 -6590819806697898649       1.000000
# 9 -9223121837663643404 -6558712014192834002       1.584963

# %%
interactions_train_df, interactions_test_df = train_test_split(interactions_full_df,
                                   stratify=interactions_full_df['personId'], 
                                   test_size=0.20,
                                   random_state=42)

print('# interactions on Train set: %d' % len(interactions_train_df))
print('# interactions on Test set: %d' % len(interactions_test_df))
# Out:
# # interactions on Train set: 31284
# # interactions on Test set: 7822

# %%
interactions_train_df, interactions_test_df = train_test_split(interactions_full_df,
                                   stratify=interactions_full_df['personId'], 
                                   test_size=0.20,
                                   random_state=42)

print('# interactions on Train set: %d' % len(interactions_train_df))
print('# interactions on Test set: %d' % len(interactions_test_df))
# Out:
# # interactions on Train set: 31284
# # interactions on Test set: 7822

# %%
#Indexing by personId to speed up the searches during evaluation
interactions_full_indexed_df = interactions_full_df.set_index('personId')
interactions_train_indexed_df = interactions_train_df.set_index('personId')
interactions_test_indexed_df = interactions_test_df.set_index('personId')

# %%
def get_items_interacted(person_id, interactions_df):
    # Get the user's data and merge in the movie information.
    interacted_items = interactions_df.loc[person_id]['contentId']
    return set(interacted_items if type(interacted_items) == pd.Series else [interacted_items])

# %%
#Top-N accuracy metrics consts
EVAL_RANDOM_SAMPLE_NON_INTERACTED_ITEMS = 100

class ModelEvaluator:


    def get_not_interacted_items_sample(self, person_id, sample_size, seed=42):
        interacted_items = get_items_interacted(person_id, interactions_full_indexed_df)
        all_items = set(articles_df['contentId'])
        non_interacted_items = all_items - interacted_items

        random.seed(seed)
        non_interacted_items_sample = random.sample(non_interacted_items, sample_size)
        return set(non_interacted_items_sample)

    def _verify_hit_top_n(self, item_id, recommended_items, topn):        
            try:
                index = next(i for i, c in enumerate(recommended_items) if c == item_id)
            except:
                index = -1
            hit = int(index in range(0, topn))
            return hit, index

    def evaluate_model_for_user(self, model, person_id):
        #Getting the items in test set
        interacted_values_testset = interactions_test_indexed_df.loc[person_id]
        if type(interacted_values_testset['contentId']) == pd.Series:
            person_interacted_items_testset = set(interacted_values_testset['contentId'])
        else:
            person_interacted_items_testset = set([int(interacted_values_testset['contentId'])])  
        interacted_items_count_testset = len(person_interacted_items_testset) 

        #Getting a ranked recommendation list from a model for a given user
        person_recs_df = model.recommend_items(person_id, 
                                               items_to_ignore=get_items_interacted(person_id, 
                                                                                    interactions_train_indexed_df), 
                                               topn=10000000000)

        hits_at_5_count = 0
        hits_at_10_count = 0
        #For each item the user has interacted in test set
        for item_id in person_interacted_items_testset:
            #Getting a random sample (100) items the user has not interacted 
            #(to represent items that are assumed to be no relevant to the user)
            non_interacted_items_sample = self.get_not_interacted_items_sample(person_id, 
                                                                          sample_size=EVAL_RANDOM_SAMPLE_NON_INTERACTED_ITEMS, 
                                                                          seed=item_id%(2**32))

            #Combining the current interacted item with the 100 random items
            items_to_filter_recs = non_interacted_items_sample.union(set([item_id]))

            #Filtering only recommendations that are either the interacted item or from a random sample of 100 non-interacted items
            valid_recs_df = person_recs_df[person_recs_df['contentId'].isin(items_to_filter_recs)]                    
            valid_recs = valid_recs_df['contentId'].values
            #Verifying if the current interacted item is among the Top-N recommended items
            hit_at_5, index_at_5 = self._verify_hit_top_n(item_id, valid_recs, 5)
            hits_at_5_count += hit_at_5
            hit_at_10, index_at_10 = self._verify_hit_top_n(item_id, valid_recs, 10)
            hits_at_10_count += hit_at_10

        #Recall is the rate of the interacted items that are ranked among the Top-N recommended items, 
        #when mixed with a set of non-relevant items
        recall_at_5 = hits_at_5_count / float(interacted_items_count_testset)
        recall_at_10 = hits_at_10_count / float(interacted_items_count_testset)

        person_metrics = {'hits@5_count':hits_at_5_count, 
                          'hits@10_count':hits_at_10_count, 
                          'interacted_count': interacted_items_count_testset,
                          'recall@5': recall_at_5,
                          'recall@10': recall_at_10}
        return person_metrics

    def evaluate_model(self, model):
        #print('Running evaluation for users')
        people_metrics = []
        for idx, person_id in enumerate(list(interactions_test_indexed_df.index.unique().values)):
            #if idx % 100 == 0 and idx > 0:
            #    print('%d users processed' % idx)
            person_metrics = self.evaluate_model_for_user(model, person_id)  
            person_metrics['_person_id'] = person_id
            people_metrics.append(person_metrics)
        print('%d users processed' % idx)

        detailed_results_df = pd.DataFrame(people_metrics) \
                            .sort_values('interacted_count', ascending=False)
        
        global_recall_at_5 = detailed_results_df['hits@5_count'].sum() / float(detailed_results_df['interacted_count'].sum())
        global_recall_at_10 = detailed_results_df['hits@10_count'].sum() / float(detailed_results_df['interacted_count'].sum())
        
        global_metrics = {'modelName': model.get_model_name(),
                          'recall@5': global_recall_at_5,
                          'recall@10': global_recall_at_10}    
        return global_metrics, detailed_results_df
    
model_evaluator = ModelEvaluator()

# %%
#Computes the most popular items
item_popularity_df = interactions_full_df.groupby('contentId')['eventStrength'].sum().sort_values(ascending=False).reset_index()
item_popularity_df.head(10)
# Out:
#              contentId  eventStrength
# 0 -4029704725707465084     307.733799
# 1 -6783772548752091658     233.762157
# 2  -133139342397538859     228.024567
# 3 -8208801367848627943     197.107608
# 4 -6843047699859121724     193.825208
# 5  8224860111193157980     189.044680
# 6 -2358756719610361882     183.110951
# 7  2581138407738454418     180.282876
# 8  7507067965574797372     179.094002
# 9  1469580151036142903     170.548969

# %%
class PopularityRecommender:
    
    MODEL_NAME = 'Popularity'
    
    def __init__(self, popularity_df, items_df=None):
        self.popularity_df = popularity_df
        self.items_df = items_df
        
    def get_model_name(self):
        return self.MODEL_NAME
        
    def recommend_items(self, user_id, items_to_ignore=[], topn=10, verbose=False):
        # Recommend the more popular items that the user hasn't seen yet.
        recommendations_df = self.popularity_df[~self.popularity_df['contentId'].isin(items_to_ignore)] \
                               .sort_values('eventStrength', ascending = False) \
                               .head(topn)

        if verbose:
            if self.items_df is None:
                raise Exception('"items_df" is required in verbose mode')

            recommendations_df = recommendations_df.merge(self.items_df, how = 'left', 
                                                          left_on = 'contentId', 
                                                          right_on = 'contentId')[['eventStrength', 'contentId', 'title', 'url', 'lang']]


        return recommendations_df
    
popularity_model = PopularityRecommender(item_popularity_df, articles_df)

# %%
print('Evaluating Popularity recommendation model...')
pop_global_metrics, pop_detailed_results_df = model_evaluator.evaluate_model(popularity_model)
print('\nGlobal metrics:\n%s' % pop_global_metrics)
pop_detailed_results_df.head(10)
# Out:
# Evaluating Popularity recommendation model...
# 1139 users processed
#
# Global metrics:
# {'modelName': 'Popularity', 'recall@5': 0.24060342623369982, 'recall@10': 0.37471234978266427}
#               _person_id  hits@10_count  hits@5_count  interacted_count  \
# 76   3609194402293569455             50            28               192
# 17  -2626634673110551643             25            12               134
# 16  -1032019229384696495             25            17               130
# 10  -1443636648652872475              8             5               117
# 82  -2979881261169775358             38            22                88
# 161 -3596626804281480007             17            11                80
# 65   1116121227607581999             33            24                73
# 81    692689608292948411             25            16                69
# 106 -9016528795238256703             20            13                69
# 52   3636910968448833585             24            20                68
#
#      recall@10  recall@5
# 76    0.260417  0.145833
# 17    0.186567  0.089552
# 16    0.192308  0.130769
# 10    0.068376  0.042735
# 82    0.431818  0.250000
# 161   0.212500  0.137500
# 65    0.452055  0.328767
# 81    0.362319  0.231884
# 106   0.289855  0.188406
# 52    0.352941  0.294118

# %%
#Content-Based Filtering model¶


#Ignoring stopwords (words with no semantics) from English and Portuguese (as we have a corpus with mixed languages)
stopwords_list = stopwords.words('english') + stopwords.words('portuguese')

#Trains a model whose vectors size is 5000, composed by the main unigrams and bigrams found in the corpus, ignoring stopwords
vectorizer = TfidfVectorizer(analyzer='word',
                     ngram_range=(1, 2),
                     min_df=0.003,
                     max_df=0.5,
                     max_features=5000,
                     stop_words=stopwords_list)

item_ids = articles_df['contentId'].tolist()
tfidf_matrix = vectorizer.fit_transform(articles_df['title'] + "" + articles_df['text'])
tfidf_feature_names = vectorizer.get_feature_names()
tfidf_matrix
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# C:\Users\amrender.yadav\AppData\Local\Continuum\Anaconda3\lib\site-packages\nltk\corpus\util.py in __load(self)
#      79             except LookupError as e:
# ---> 80                 try: root = nltk.data.find('{}/{}'.format(self.subdir, zip_name))
#      81                 except LookupError: raise e
#
# C:\Users\amrender.yadav\AppData\Local\Continuum\Anaconda3\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     652     resource_not_found = '\n%s\n%s\n%s' % (sep, msg, sep)
# --> 653     raise LookupError(resource_not_found)
#     654
#
# LookupError:
# **********************************************************************
#   Resource 'corpora/stopwords.zip/stopwords/' not found.  Please
#   use the NLTK Downloader to obtain the resource:  >>>
#   nltk.download()
#   Searched in:
#     - 'C:\\Users\\amrender.yadav/nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
#     - 'C:\\Users\\amrender.yadav\\AppData\\Local\\Continuum\\Anaconda3\\nltk_data'
#     - 'C:\\Users\\amrender.yadav\\AppData\\Local\\Continuum\\Anaconda3\\lib\\nltk_data'
#     - 'C:\\Users\\amrender.yadav\\AppData\\Roaming\\nltk_data'
# **********************************************************************
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# <ipython-input-47-be024954c4f2> in <module>()
#       3
#       4 #Ignoring stopwords (words with no semantics) from English and Portuguese (as we have a corpus with mixed languages)
# ----> 5 stopwords_list = stopwords.words('english') + stopwords.words('portuguese')
#       6
#       7 #Trains a model whose vectors size is 5000, composed by the main unigrams and bigrams found in the corpus, ignoring stopwords
#
# C:\Users\amrender.yadav\AppData\Local\Continuum\Anaconda3\lib\site-packages\nltk\corpus\util.py in __getattr__(self, attr)
#     114             raise AttributeError("LazyCorpusLoader object has no attribute '__bases__'")
#     115
# --> 116         self.__load()
#     117         # This looks circular, but its not, since __load() changes our
#     118         # __class__ to something new:
#
# C:\Users\amrender.yadav\AppData\Local\Continuum\Anaconda3\lib\site-packages\nltk\corpus\util.py in __load(self)
#      79             except LookupError as e:
#      80                 try: root = nltk.data.find('{}/{}'.format(self.subdir, zip_name))
# ---> 81                 except LookupError: raise e
#      82
#      83         # Load the corpus.
#
# C:\Users\amrender.yadav\AppData\Local\Continuum\Anaconda3\lib\site-packages\nltk\corpus\util.py in __load(self)
#      76         else:
#      77             try:
# ---> 78                 root = nltk.data.find('{}/{}'.format(self.subdir, self.__name))
#      79             except LookupError as e:
#      80                 try: root = nltk.data.find('{}/{}'.format(self.subdir, zip_name))
#
# C:\Users\amrender.yadav\AppData\Local\Continuum\Anaconda3\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     651     sep = '*' * 70
#     652     resource_not_found = '\n%s\n%s\n%s' % (sep, msg, sep)
# --> 653     raise LookupError(resource_not_found)
#     654
#     655
#
# LookupError:
# **********************************************************************
#   Resource 'corpora/stopwords' not found.  Please use the NLTK
#   Downloader to obtain the resource:  >>> nltk.download()
#   Searched in:
#     - 'C:\\Users\\amrender.yadav/nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
#     - 'C:\\Users\\amrender.yadav\\AppData\\Local\\Continuum\\Anaconda3\\nltk_data'
#     - 'C:\\Users\\amrender.yadav\\AppData\\Local\\Continuum\\Anaconda3\\lib\\nltk_data'
#     - 'C:\\Users\\amrender.yadav\\AppData\\Roaming\\nltk_data'
# **********************************************************************

# %%
def get_item_profile(item_id):
    idx = item_ids.index(item_id)
    item_profile = tfidf_matrix[idx:idx+1]
    return item_profile

def get_item_profiles(ids):
    item_profiles_list = [get_item_profile(x) for x in ids]
    item_profiles = scipy.sparse.vstack(item_profiles_list)
    return item_profiles

def build_users_profile(person_id, interactions_indexed_df):
    interactions_person_df = interactions_indexed_df.loc[person_id]
    user_item_profiles = get_item_profiles(interactions_person_df['contentId'])
    
    user_item_strengths = np.array(interactions_person_df['eventStrength']).reshape(-1,1)
    #Weighted average of item profiles by the interactions strength
    user_item_strengths_weighted_avg = np.sum(user_item_profiles.multiply(user_item_strengths), axis=0) / np.sum(user_item_strengths)
    user_profile_norm = sklearn.preprocessing.normalize(user_item_strengths_weighted_avg)
    return user_profile_norm

def build_users_profiles(): 
    interactions_indexed_df = interactions_full_df[interactions_full_df['contentId'] \
                                                   .isin(articles_df['contentId'])].set_index('personId')
    user_profiles = {}
    for person_id in interactions_indexed_df.index.unique():
        user_profiles[person_id] = build_users_profile(person_id, interactions_indexed_df)
    return user_profiles

# %%
user_profiles = build_users_profiles()
len(user_profiles)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-07570ed37db5> in <module>()
# ----> 1 user_profiles = build_users_profiles()
#       2 len(user_profiles)
#
# <ipython-input-26-89deade9e1e3> in build_users_profiles()
#      23     user_profiles = {}
#      24     for person_id in interactions_indexed_df.index.unique():
# ---> 25         user_profiles[person_id] = build_users_profile(person_id, interactions_indexed_df)
#      26     return user_profiles
#
# <ipython-input-26-89deade9e1e3> in build_users_profile(person_id, interactions_indexed_df)
#      11 def build_users_profile(person_id, interactions_indexed_df):
#      12     interactions_person_df = interactions_indexed_df.loc[person_id]
# ---> 13     user_item_profiles = get_item_profiles(interactions_person_df['contentId'])
#      14
#      15     user_item_strengths = np.array(interactions_person_df['eventStrength']).reshape(-1,1)
#
# <ipython-input-26-89deade9e1e3> in get_item_profiles(ids)
#       5
#       6 def get_item_profiles(ids):
# ----> 7     item_profiles_list = [get_item_profile(x) for x in ids]
#       8     item_profiles = scipy.sparse.vstack(item_profiles_list)
#       9     return item_profiles
#
# <ipython-input-26-89deade9e1e3> in <listcomp>(.0)
#       5
#       6 def get_item_profiles(ids):
# ----> 7     item_profiles_list = [get_item_profile(x) for x in ids]
#       8     item_profiles = scipy.sparse.vstack(item_profiles_list)
#       9     return item_profiles
#
# <ipython-input-26-89deade9e1e3> in get_item_profile(item_id)
#       1 def get_item_profile(item_id):
# ----> 2     idx = item_ids.index(item_id)
#       3     item_profile = tfidf_matrix[idx:idx+1]
#       4     return item_profile
#       5
#
# NameError: name 'item_ids' is not defined
